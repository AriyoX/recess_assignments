# %% [markdown]
# <h1><center>AHUMUZA ARIYO NIMUSIIMA</center></h1>
# <h2><center>PYTHON AFTERNOON CLASS ASSIGNMENT</center></h2>

# %% [markdown]
# <h3>DATA ANALYSIS WITH PANDAS</h3>

# %%
# Import Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# <p><b>Question 1</b></p>

# %%
series1 = pd.Series([4, 65, 436, 3, 9])
series2 = pd.Series([7, 0, 3, 897, 9])

# Compare the elements of the two series
comparison = series1 == series2

# Print the comparison result
print(comparison)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# <p><b>Question 2</b></p>

# %%
series1 = pd.Series([2, 4, 6, 8, 14])
series2 = pd.Series([1, 3, 5, 7, 9])

# Addition
addition = series1 + series2
print("Addition:")
print(addition)

# Subtraction
subtraction = series1 - series2
print("\nSubtraction:")
print(subtraction)

# Multiplication
multiplication = series1 * series2
print("\nMultiplication:")
print(multiplication)

# Division
division = series1 / series2
print("\nDivision:")
print(division)
# Out:
# Addition:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
#
# Subtraction:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
#
# Multiplication:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
#
# Division:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %% [markdown]
# <p><b>Question 3</b></p>

# %%
dictionary1 = {'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}

# Convert dictionary to series
series = pd.Series(dictionary1)

# Print the series
print(series)
# Out:
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %% [markdown]
# <p><b>Question 4</b></p>

# %%
series1 = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])

# Create Pandas array with dtype string
pd_arr = pd.array(series1)
  
# Print the formed array
print(pd_arr)
# Out:
# <PandasArray>
# ['Love', 800, 'Joy', 789.9, 'Peace', True]
# Length: 6, dtype: object

# %% [markdown]
# <p><b>Question 5</b></p>

# %%
df = pd.read_csv('AfricaCupofNationsMatches.csv')

# Find the most frequent value
most_frequent = df['HomeTeamGoals'].value_counts().idxmax()

# Display most frequent value
print("Most Frequent Value: ",<p><b>Question 1</b></p> most_frequent)

# Replace everything else as 'Other'
df.loc[df['HomeTeamGoals'] != most_frequent, 'HomeTeamGoals'] = 'Other'

# Print the modified series
print()
print()
print(df['HomeTeamGoals'])
# Out:
# Most Frequent Value:  1.0
#
#
# 0        1.0
# 1      Other
# 2      Other
# 3      Other
# 4        1.0
#        ...
# 617    Other
# 618      1.0
# 619    Other
# 620    Other
# 621    Other
# Name: HomeTeamGoals, Length: 622, dtype: object

# %% [markdown]
# <h3>DATAFRAMES</h3>

# %% [markdown]
# <p><b>Question 1</b></p>

# %%
# Read the dataset
df = pd.read_csv('AfricaCupofNationsMatches.csv')
df
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# <p><b>Question 2</b></p>

# %%
# First 7 rows
df.head(7)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %% [markdown]
# <p><b>Question 3</b></p>

# %%
# Select specific columns
selected_columns = df[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals']]

# Display the selected columns
print(selected_columns)
# Out:
#         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]

# %% [markdown]
# <p><b>Question 4</b></p>

# %%
# Select rows where 'Egypt' appears
egypt_rows = df[df['HomeTeam'] == 'Egypt']

# Display the selected rows
print(egypt_rows)
# Out:
#     Year      Date  Time  HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 3   1959  22-May-59   NaN    Egypt   Ethiopia            4.0            0.0
# 5   1959  29-May-59   NaN    Egypt      Sudan            2.0            1.0
# 7   1962  18-Jan-62   NaN    Egypt     Uganda            2.0            1.0
# 13  1963  24-Nov-63   NaN    Egypt    Nigeria            6.0            3.0
# 14  1963  26-Nov-63   NaN    Egypt      Sudan            2.0            2.0
# 16  1963  30-Nov-63   NaN    Egypt   Ethiopia            3.0            0.0
#
#                 Stage SpecialWinConditions                 Stadium  \
# 3    Final Tournament                  NaN   Prince Farouk Stadium
# 5    Final Tournament                  NaN   Prince Farouk Stadium
# 7          Semifinals                  NaN  Hailé Sélassié Stadium
# 13            Group B                  NaN   Kumasi Sports Stadium
# 14            Group B                  NaN   Kumasi Sports Stadium
# ...

# %% [markdown]
# <p><b>Question 5</b></p>

# %%
# Count the number of rows and columns
num_rows, num_columns = df.shape

# Display the number of rows and columns
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 622
# Number of columns: 12

# %% [markdown]
# <p><b>Question 6</b></p>

# %%
# Select rows where 'Attendance' is missing
missing_attendance_rows = df[df['Attendance'].isnull()]

# Display the selected rows
print(missing_attendance_rows)
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
# ...

# %% [markdown]
# <p><b>Question 7</b></p>

# %%
# Select rows where 'HomeTeamGoals' are between 3 and 6
selected_rows = df[(df['HomeTeamGoals'] >= 3) & (df['HomeTeamGoals'] <= 6)]

# Display the selected rows
print(selected_rows)
# Out:
#      Year                         Date   Time    HomeTeam     AwayTeam  \
# 2    1957                     16-Feb-57    NaN     Egypt      Ethiopia
# 3    1959                     22-May-59    NaN      Egypt     Ethiopia
# 6    1962                     14-Jan-62    NaN  Ethiopia       Tunisia
# 8    1962                     20-Jan-62    NaN   Tunisia        Uganda
# 9    1962                     21-Jan-62    NaN  Ethiopia         Egypt
# ..    ...                           ...    ...        ...          ...
# 553  2017  20 January 2017 (2017-01-20)  20:00   Morocco          Togo
# 585  2019     27 June 2019 (2019-06-27)  22:00     Kenya      Tanzania
# 595  2019     24 June 2019 (2019-06-24)  22:00      Mali    Mauritania
# 608  2019      6 July 2019 (2019-07-06)  18:00   Nigeria      Cameroon
# 611  2019      7 July 2019 (2019-07-07)  21:00   Algeria        Guinea
#
#      HomeTeamGoals  AwayTeamGoals              Stage    SpecialWinConditions  \
# ...

# %% [markdown]
# <p><b>Question 8</b></p>

# %%
# Change 'AwayTeamGoals' in the 3rd row to 10
df.at[2, 'AwayTeamGoals'] = 10

# Display the updated DataFrame
df.head()
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2           10.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
#
#                                 SpecialWinConditions                Stadium  \
# 0                                                NaN      Municipal Stadium
# 1  Ethiopia  wins due to disqualification of othe...                    NaN
# 2                                                NaN      Municipal Stadium
# ...

# %% [markdown]
# <p><b>Question 9</b></p>

# %%
# Sort the DataFrame
sorted_df = df.sort_values(by=['HomeTeam', 'HomeTeamGoals'], ascending=[True, False])

# Display the sorted DataFrame
print(sorted_df)
# Out:
#      Year                         Date           Time    HomeTeam  \
# 205  1990                      2-Mar-90            NaN   Algeria
# 29   1968                     14-Jan-68            NaN   Algeria
# 135  1980                     16-Mar-80            NaN   Algeria
# 164  1984                      5-Mar-84            NaN   Algeria
# 171  1984                     17-Mar-84            NaN   Algeria
# ..    ...                           ...            ...        ...
# 521  2012                     12-Feb-12  20:30[note 1]    Zambia
# 549  2017  23 January 2017 (2017-01-23)          20:00  Zimbabwe
# 398  2004                     25-Jan-04          16:30  Zimbabwe
# 437  2006                     23-Jan-06          20:00  Zimbabwe
# 575  2019     30 June 2019 (2019-06-30)          21:00  Zimbabwe
#
#          AwayTeam  HomeTeamGoals  AwayTeamGoals              Stage  \
# 205       Nigeria            5.0            1.0            Group A
# ...

# %% [markdown]
# <p><b>Question 10</b></p>

# %%
# Get list from DataFrame column headers
column_headers = df.columns.tolist()

# Display the list of column headers
print(column_headers)
# Out:
# ['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City', 'Attendance']

# %% [markdown]
# <p><b>Question 11</b></p>

# %%
# Create a new column
new_column = pd.Series(['Value1', 'Value2', 'Value3'])

# Append the new column to the DataFrame
df['NewColumn'] = new_column

# Display the updated DataFrame
print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# <p><b>Question 12:</b></p>

# %%
# Create new rows
new_rows = [{'HomeTeam': 'Team1', 'AwayTeam': 'Team2', 'HomeTeamGoals': 2, 'AwayTeamGoals': 1},
            {'HomeTeam': 'Team3', 'AwayTeam': 'Team4', 'HomeTeamGoals': 0, 'AwayTeamGoals': 3}]

# Append the new rows to the DataFrame
df = df.append(new_rows, ignore_index=True)

# Display the updated DataFrame
df.tail(10)
# Out:
#        Year                      Date   Time   HomeTeam  AwayTeam  \
# 618  2019.0  14 July 2019 (2019-07-14)  18:00  Senegal    Tunisia
# 619  2019.0  14 July 2019 (2019-07-14)  21:00  Algeria    Nigeria
# 620  2019.0  17 July 2019 (2019-07-17)  21:00  Tunisia    Nigeria
# 621  2019.0  19 July 2019 (2019-07-19)  21:00  Senegal    Algeria
# 622     NaN                        NaN    NaN     Team1     Team2
# 623     NaN                        NaN    NaN     Team3     Team4
# 624     NaN                        NaN    NaN     Team1     Team2
# 625     NaN                        NaN    NaN     Team3     Team4
# 626     NaN                        NaN    NaN     Team1     Team2
# 627     NaN                        NaN    NaN     Team3     Team4
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 618            1.0            0.0           Semi-finals
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# ...

# %% [markdown]
# <p><b>Question 13</b></p>

# %%
# Change 'Uganda' to 'China' in 'AwayTeam' column
df.loc[df['AwayTeam'] == 'Uganda', 'AwayTeam'] = 'China'

# Display the updated DataFrame
print(df)
# Out:
#        Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957.0  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1    1957.0  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2    1957.0  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3    1959.0  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4    1959.0  25-May-59   NaN     Sudan        Ethiopia            1.0
# ..      ...        ...   ...        ...            ...            ...
# 623     NaN        NaN   NaN      Team3          Team4            0.0
# 624     NaN        NaN   NaN      Team1          Team2            2.0
# 625     NaN        NaN   NaN      Team3          Team4            0.0
# 626     NaN        NaN   NaN      Team1          Team2            2.0
# 627     NaN        NaN   NaN      Team3          Team4            0.0
#
#      AwayTeamGoals             Stage  \
# 0              2.0        Semifinals
# 1              NaN        Semifinals
# ...

# %% [markdown]
# <p><b>Question 14</b></p>

# %%
# Reset index
df = df.reset_index(drop=True)

# Display the updated DataFrame
print(df)
# Out:
#        Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957.0  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1    1957.0  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2    1957.0  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3    1959.0  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4    1959.0  25-May-59   NaN     Sudan        Ethiopia            1.0
# ..      ...        ...   ...        ...            ...            ...
# 623     NaN        NaN   NaN      Team3          Team4            0.0
# 624     NaN        NaN   NaN      Team1          Team2            2.0
# 625     NaN        NaN   NaN      Team3          Team4            0.0
# 626     NaN        NaN   NaN      Team1          Team2            2.0
# 627     NaN        NaN   NaN      Team3          Team4            0.0
#
#      AwayTeamGoals             Stage  \
# 0              2.0        Semifinals
# 1              NaN        Semifinals
# ...

# %% [markdown]
# <p><b>Question 15</b></p>

# %%
# Check if 'Stadium' column is present
if 'Stadium' in df.columns:
    print("The 'Stadium' column is present in the DataFrame.")
else:
    print("The 'Stadium' column is not present in the DataFrame.")
# Out:
# The 'Stadium' column is present in the DataFrame.

# %% [markdown]
# <p><b>Question 16</b></p>

# %%
# Convert 'AwayTeamGoals' datatype to float
df['AwayTeamGoals'] = df['AwayTeamGoals'].astype(float)

# Display the updated DataFrame
print(df)
# Out:
#        Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957.0  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1    1957.0  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2    1957.0  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3    1959.0  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4    1959.0  25-May-59   NaN     Sudan        Ethiopia            1.0
# ..      ...        ...   ...        ...            ...            ...
# 623     NaN        NaN   NaN      Team3          Team4            0.0
# 624     NaN        NaN   NaN      Team1          Team2            2.0
# 625     NaN        NaN   NaN      Team3          Team4            0.0
# 626     NaN        NaN   NaN      Team1          Team2            2.0
# 627     NaN        NaN   NaN      Team3          Team4            0.0
#
#      AwayTeamGoals             Stage  \
# 0              2.0        Semifinals
# 1              NaN        Semifinals
# ...

# %% [markdown]
# <p><b>Question 17</b></p>

# %%
# Remove the last 10 rows
df = df[:-10]

# Display the updated DataFrame
print(df)
# Out:
#        Year                      Date   Time         HomeTeam        AwayTeam  \
# 0    1957.0                  10-Feb-57    NaN          Sudan            Egypt
# 1    1957.0                  10-Feb-57    NaN       Ethiopia     South Africa
# 2    1957.0                  16-Feb-57    NaN          Egypt         Ethiopia
# 3    1959.0                  22-May-59    NaN           Egypt        Ethiopia
# 4    1959.0                  25-May-59    NaN          Sudan         Ethiopia
# ..      ...                        ...    ...             ...             ...
# 603  2019.0  29 June 2019 (2019-06-29)  22:00          Benin    Guinea-Bissau
# 604  2019.0   2 July 2019 (2019-07-02)  18:00          Benin         Cameroon
# 605  2019.0   2 July 2019 (2019-07-02)  18:00  Guinea-Bissau            Ghana
# 606  2019.0   5 July 2019 (2019-07-05)  18:00        Morocco            Benin
# 607  2019.0   5 July 2019 (2019-07-05)  21:00         Uganda          Senegal
#
# ...

# %% [markdown]
# <p><b>Question 18</b></p>

# %%
# Iterate over rows
for index, row in df.iterrows():
    print(row['HomeTeam'], row['AwayTeam'], row['HomeTeamGoals'], row['AwayTeamGoals'])
# Out:
# Sudan   Egypt 1.0 2.0
# Ethiopia   South Africa nan nan
# Egypt   Ethiopia 4.0 10.0
# Egypt  Ethiopia 4.0 0.0
# Sudan   Ethiopia 1.0 0.0
# Egypt  Sudan 2.0 1.0
# Ethiopia   Tunisia 4.0 2.0
# Egypt  Uganda 2.0 1.0
# Tunisia   Uganda 3.0 0.0
# Ethiopia  Egypt 4.0 2.0
# Ghana   Tunisia 1.0 1.0
# Ghana   Ethiopia 2.0 0.0
# Ethiopia   Tunisia 4.0 2.0
# Egypt  Nigeria 6.0 3.0
# Egypt  Sudan 2.0 2.0
# Sudan   Nigeria 4.0 0.0
# Egypt  Ethiopia 3.0 0.0
# Ghana   Sudan 3.0 0.0
# Tunisia   Ethiopia 4.0 0.0
# Senegal   Tunisia 0.0 0.0
# Senegal   Ethiopia 5.0 1.0
# Ghana   Congo-Léopoldville 5.0 2.0
# Ivory Coast   Congo-Léopoldville 3.0 0.0
# Ghana   Ivory Coast 4.0 1.0
# Senegal   Ivory Coast 0.0 1.0
# Ghana   Tunisia 3.0 2.0
# Ethiopia   Uganda 2.0 1.0
# Ivory Coast   Algeria 3.0 0.0
# Ethiopia   Ivory Coast 1.0 0.0
# Algeria   Uganda 4.0 0.0
# Ivory Coast   Uganda 2.0 1.0
# Ethiopia   Algeria 3.0 1.0
# Ghana   Senegal 2.0 2.0
# Congo-Kinshasa   Congo-Brazzaville 3.0 0.0
# ...

# %% [markdown]
# <p><b>Question 19</b></p>

# %%
# Change column order
df = df[['AwayTeam', 'HomeTeam', 'AwayTeamGoals', 'HomeTeamGoals']]

# Display the updated DataFrame
print(df)
# Out:
#            AwayTeam        HomeTeam  AwayTeamGoals  HomeTeamGoals
# 0             Egypt          Sudan             2.0            1.0
# 1      South Africa       Ethiopia             NaN            NaN
# 2          Ethiopia          Egypt            10.0            4.0
# 3          Ethiopia           Egypt            0.0            4.0
# 4          Ethiopia          Sudan             0.0            1.0
# ..              ...             ...            ...            ...
# 603   Guinea-Bissau          Benin             0.0            0.0
# 604        Cameroon          Benin             0.0            0.0
# 605           Ghana  Guinea-Bissau             2.0            0.0
# 606           Benin        Morocco             1.0            1.0
# 607         Senegal         Uganda             1.0            0.0
#
# [608 rows x 4 columns]

# %% [markdown]
# <p><b>Question 20</b></p>

# %%
# Delete rows with 0 in 'HomeTeamGoals'
df = df[df['HomeTeamGoals'] != 0]

# Display the updated DataFrame
print(df)
# Out:
#            AwayTeam   HomeTeam  AwayTeamGoals  HomeTeamGoals
# 0             Egypt     Sudan             2.0            1.0
# 1      South Africa  Ethiopia             NaN            NaN
# 2          Ethiopia     Egypt            10.0            4.0
# 3          Ethiopia      Egypt            0.0            4.0
# 4          Ethiopia     Sudan             0.0            1.0
# ..              ...        ...            ...            ...
# 595      Mauritania      Mali             1.0            4.0
# 596            Mali   Tunisia             1.0            1.0
# 600   Guinea-Bissau  Cameroon             0.0            2.0
# 601           Benin     Ghana             2.0            2.0
# 606           Benin   Morocco             1.0            1.0
#
# [485 rows x 4 columns]
